# %% [markdown]
# ###Trying to find out how demographic factors (e.g., age, sex) relate to suspicious activity reports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_kyc = pd.read_csv('/content/df_kyc.csv')
df_labels = pd.read_csv('/content/df_label.csv')

# %%
df_labels_grouped_by_custid = df_labels.groupby('Customer_ID')['SAR'].max().reset_index()
df_labels_grouped_by_custid.head(5)
# Out:
#    Customer_ID  SAR
# 0            1    1
# 1            2    0
# 2            3    1
# 3            4    0
# 4            5    1

# %%
df_kyc_labels_merged = df_labels_grouped_by_custid.merge(df_kyc, on='Customer_ID', how='inner')

# %%
df_kyc_labels_merged.head()
# Out:
#    Customer_ID  SAR  Age     Sex  High_Risk_Country  Vulnerable_Area  \
# 0            1    1   28    Male              False            False
# 1            2    0   80    Male              False            False
# 2            3    1   79  Female              False            False
# 3            4    0   34  Female              False            False
# 4            5    1   58    Male              False            False
#
#    Intention_International_Payments  Intention_Cash_Deposits
# 0                              True                    False
# 1                             False                    False
# 2                             False                    False
# 3                             False                    False
# 4                             False                    False

# %%
sns.countplot(x='Sex', hue='SAR', data=df_kyc_labels_merged)
plt.title('Number of Occurrences of SAR by Sex')
plt.show()

# %% [markdown]
# Conclusion : Sex might not strongly correlate with suspicious activity

# %%
sns.countplot(x='Vulnerable_Area', hue='SAR', data=df_kyc_labels_merged)
plt.title('Number of Occurrences of SAR by Vulnerable Area')
plt.show()

# %% [markdown]
# This predicts the SAR have been identified from Non Vulnerable Areas as well. There are far fewer SARs in vulnerable areas, both in absolute terms and relative to non-vulnerable areas.
#
#
# **Conclusion** : The "vulnerable area" might not strongly correlate with suspicious activity

# %%
# prompt: give a plot for age range and SAR



# Assuming 'df_kyc_labels_merged' DataFrame is available from the previous code.

plt.figure(figsize=(20, 6))
sns.countplot(x='Age', hue='SAR', data=df_kyc_labels_merged)
plt.title('Number of Occurrences of SAR by Age Range')
plt.xlabel('Age Range')
plt.ylabel('Count')
plt.show()
